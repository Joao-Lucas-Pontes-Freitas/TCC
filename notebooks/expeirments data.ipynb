# %% [markdown]
# # 1. Configuração de Ambiente
#
# Imports agrupados por tipo e carregamento das variáveis de ambiente.

# %%
# %% Imports padrão
import os
import sys
from pathlib import Path
from datetime import datetime
import shutil
import json

# %% Imports de Data Science
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets, metrics, model_selection

# %% Configuração de paths e imports dos módulos personalizados
sys.path.insert(0, os.path.abspath(os.path.join('..', 'src')))
from mongo import mongo_insert
from metrics import evaluate_metrics, collect_performance_over_time, compute_learning_curve
# Out:
# /home/joao/miniconda3/envs/tcc-env/lib/python3.9/site-packages/sklearn/utils/fixes.py:28: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version  # type: ignore

# %% [markdown]
# # 2. Carregamento e Pré-processamento de Dados
#
# Carrega o dataset (definido por variável), divide em treino e teste e prepara diretórios temporários.

# %%
# %% Configurações de dataset
DATASET_NAME = 'imdb'
RANDOM_STATE = 1

# %% Carregamento
df = pd.read_csv(f'../data/{DATASET_NAME}.csv')
df.columns = df.columns.str.lower()
df.columns

X = df.drop(columns='sentiment')
y = df['sentiment']

# %% Split
X_train, X_test, y_train, y_test = model_selection.train_test_split(
    X, y, random_state=RANDOM_STATE, stratify=y
)

# %% Diretórios temporários
TMP_ROOT = Path('../results/tmp') / DATASET_NAME
if TMP_ROOT.exists():
    shutil.rmtree(TMP_ROOT)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((37500, 1), (12500, 1), (37500,), (12500,))

# %% [markdown]
# # 3. Configuração e Execução do AutoSklearn
#
# Funções utilitárias para rodar o AutoSklearn com ou sem ensemble e coletar informações essenciais do processo.

# %%
import autosklearn.classification
import autosklearn.metrics

# %% Parâmetros Auto-sklearn
TIME_LIMIT_SEC = 60 * 60 * 12 # 12 horas
METRIC_SK = autosklearn.metrics.f1_weighted

def run_autosklearn(with_ensemble: bool, tmp_dir: Path):
    automl = autosklearn.classification.AutoSklearnClassifier(
        time_left_for_this_task=TIME_LIMIT_SEC,
        per_run_time_limit=int(TIME_LIMIT_SEC / 10),
        tmp_folder=str(tmp_dir),
        seed=RANDOM_STATE,
        metric=METRIC_SK,
        ensemble_kwargs={'ensemble_size': 50 if with_ensemble else 1},
        memory_limit=1024*6,  # 6GB de memória
    )
    automl.fit(X_train, y_train)
    return automl

def extract_leaderboard(automl):
    lb = automl.leaderboard(detailed=True, ensemble_only=True).sort_values('ensemble_weight', ascending=False)
    return lb.reset_index(drop=True)

def serialize_models(automl, leaderboard_df):
    def serialize_param(value):
        """Converte parâmetros para tipos serializáveis"""
        if value is None:
            return None
        elif isinstance(value, (int, float, str, bool)):
            return value
        elif isinstance(value, np.number):
            return float(value)
        elif isinstance(value, (list, tuple)):
            return [serialize_param(v) for v in value]
        elif isinstance(value, dict):
            return {k: serialize_param(v) for k, v in value.items()}
        else:
            # Para objetos complexos, tenta converter para string
            return str(value)
    
    models_serialized = []
    for (_, row), (weight, pipeline) in zip(
        leaderboard_df.iterrows(),
        automl.get_models_with_weights()
    ):
        steps_info = {}
        for name, step in pipeline.steps:
            estimator = step.choice if hasattr(step, 'choice') else step
            
            # Obtém todos os parâmetros
            try:
                raw_params = estimator.get_params(deep=False)
            except AttributeError:
                raw_params = {}
            
            filtered_params = {}
            for k, v in raw_params.items():
                try:
                    filtered_params[k] = serialize_param(v)
                except Exception as e:
                    filtered_params[k] = {"_error": str(e), "_type": type(v).__name__}
            
            steps_info[name] = {
                'algorithm': estimator.__class__.__name__,
                'parameters': filtered_params
            }

        models_serialized.append({
            'weight': float(weight),
            'cost':   float(row['cost']),
            'classifier':          steps_info.get('classifier', {}),
            'data_preprocessor':   steps_info.get('data_preprocessor', {}),
            'feature_preprocessor':steps_info.get('feature_preprocessor', {})
        })

    return {
        'total_models': len(models_serialized),
        'models':       models_serialized
    }

# %% [markdown]
# # 4. Salvamento dos Resultados no MongoDB
#
# Constrói o documento JSON final (no padrão especificado) e insere na coleção MongoDB.

# %%
def build_document(automl, leaderboard_df, with_ensemble: bool):
    metrics_obj = evaluate_metrics(automl, X_test, y_test)
    model_obj = serialize_models(automl, leaderboard_df)
    perf_time = collect_performance_over_time(automl)
    #lc_data = compute_learning_curve(automl, X_train, y_train, scoring='f1_weighted', random_state=RANDOM_STATE)
    return {
        'timeStamp': datetime.now().astimezone().isoformat(),
        'dataset': DATASET_NAME,
        'automl': 'autosklearn',
        'with_ensemble': with_ensemble,
        'metrics': metrics_obj,
        'model': {
            **model_obj,
            'graphic': {
                'performance_over_time': perf_time,
                'learning_curve': None
            }
        }
    }

# A função mongo_insert agora está no módulo mongo.py e foi importada na célula de configuração

# %% [markdown]
# # Execução
#
# Roda com e sem ensemble, monta documentos e insere no MongoDB.

# %%
# %% Execução paralela limpa
import concurrent.futures, time, warnings, logging

warnings.filterwarnings("ignore", message=".*cost of smaller/equal to 0.*")

def workflow(with_ens: bool, label: str):
    folder = TMP_ROOT / label
    automl = run_autosklearn(with_ens, folder)
    lb     = extract_leaderboard(automl)
    doc    = build_document(automl, lb, with_ens)
    mongo  = mongo_insert(doc)  # Agora usa as variáveis de ambiente carregadas internamente
    return label, {'doc': doc, 'mongo_id': mongo, 'automl': automl, 'leaderboard': lb}

start = time.time()
RESULTS = {}

with concurrent.futures.ProcessPoolExecutor(max_workers=2) as pool:
    futures = [
        pool.submit(workflow, True , 'with_ensemble'),
        pool.submit(workflow, False, 'without_ensemble')
    ]
    for fut in concurrent.futures.as_completed(futures):
        label, data = fut.result()
        RESULTS[label] = data

print(f'Tempo total: {time.time()-start:.1f}s')
RESULTS.keys()
# Out:
# /home/joao/miniconda3/envs/tcc-env/lib/python3.9/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column review has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# /home/joao/miniconda3/envs/tcc-env/lib/python3.9/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column review has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# init_gesdd failed init
# init_gesdd failed init
# init_gesdd failed init
# init_gesdd failed init
# /home/joao/miniconda3/envs/tcc-env/lib/python3.9/site-packages/autosklearn/automl.py:1860: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pd.merge(
# Erro ao inserir no MongoDB: SSL handshake failed: ac-wvjp0kv-shard-00-00.qc5bvbn.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1147) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-wvjp0kv-shard-00-02.qc5bvbn.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1147) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-wvjp0kv-shard-00-01.qc5bvbn.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1147) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 5.0s, Topology Description: <TopologyDescription id: 6888bd7f9ce780c25c75a480, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-wvjp0kv-shard-00-00.qc5bvbn.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-wvjp0kv-shard-00-00.qc5bvbn.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1147) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('ac-wvjp0kv-shard-00-01.qc5bvbn.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-wvjp0kv-shard-00-01.qc5bvbn.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1147) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('ac-wvjp0kv-shard-00-02.qc5bvbn.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-wvjp0kv-shard-00-02.qc5bvbn.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1147) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
# /home/joao/miniconda3/envs/tcc-env/lib/python3.9/site-packages/autosklearn/automl.py:1860: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pd.merge(
# Erro ao inserir no MongoDB: SSL handshake failed: ac-wvjp0kv-shard-00-00.qc5bvbn.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1147) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-wvjp0kv-shard-00-02.qc5bvbn.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1147) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-wvjp0kv-shard-00-01.qc5bvbn.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1147) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 5.0s, Topology Description: <TopologyDescription id: 6888bd9bb512e1310375a480, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-wvjp0kv-shard-00-00.qc5bvbn.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-wvjp0kv-shard-00-00.qc5bvbn.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1147) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('ac-wvjp0kv-shard-00-01.qc5bvbn.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-wvjp0kv-shard-00-01.qc5bvbn.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1147) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('ac-wvjp0kv-shard-00-02.qc5bvbn.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-wvjp0kv-shard-00-02.qc5bvbn.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1147) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
# Tempo total: 43260.4s
# dict_keys(['without_ensemble', 'with_ensemble'])

# %%
for label, result in RESULTS.items():
    print(f"Resultado para '{label}':")
    print(f"Leaderboard:")
    print(result['leaderboard'])
    print(f"Objeto json:")
    doc = result['doc']
    doc_copy = doc.copy()
    doc_copy.pop('_id', None)
    print(json.dumps(doc_copy, indent=2))
# Out:
# Resultado para 'without_ensemble':
# Leaderboard:
#    rank  ensemble_weight type      cost    duration  config_id  train_loss  \
# 0     1              1.0  lda  0.120658  558.197648        110    0.115918
#
#    seed    start_time      end_time  budget              status  \
# 0     0  1.753788e+09  1.753789e+09     0.0  StatusType.SUCCESS
#
#   data_preprocessors feature_preprocessors balancing_strategy config_origin
# 0                 []    [no_preprocessing]          weighting  Local Search
# Objeto json:
# {
#   "timeStamp": "2025-07-29T09:24:31.604812-03:00",
#   "dataset": "imdb",
#   "automl": "autosklearn",
#   "with_ensemble": false,
#   "metrics": {
#     "accuracy": 0.88144,
#     "precision": 0.8818309949388173,
#     "recall": 0.88144,
#     "balanced_f1": 0.8814096408680623,
#     "confusion_matrix": [
#       [
#         0.86544,
#         0.13456
#       ],
#       [
#         0.10256,
#         0.89744
#       ]
#     ]
#   },
#   "model": {
#     "total_models": 1,
#     "models": [
#       {
#         "weight": 1.0,
#         "cost": 0.12065809550029405,
#         "classifier": {
#           "algorithm": "LDA",
#           "parameters": {}
#         },
#         "data_preprocessor": {
#           "algorithm": "FeatTypeSplit",
#           "parameters": {
#             "column_transformer": "ColumnTransformer(sparse_threshold=0.0,\n                  transformers=[('text_transformer',\n                                 TextPreprocessingPipeline(config=Configuration(values={\n  'text_encoding:__choice__': 'tfidf_encoding',\n  'text_encoding:tfidf_encoding:analyzer': 'char',\n  'text_encoding:tfidf_encoding:binary': 'False',\n  'text_encoding:tfidf_encoding:max_df': 0.970356057565052,\n  'text_encoding:tfidf_encoding...\n  'text_feature_reduction:n_components': 573,\n})\n, dataset_properties={'signed': False, 'sparse': False}, exclude={}, feat_type={'review': 'string'}, include={}, init_params={}, steps=[('text_encoding', <autosklearn.pipeline.components.data_preprocessing.text_encoding.BagOfWordChoice object at 0x7e8ecfab4640>), ('text_feature_reduction', TextFeatureReduction(n_components=573))]),\n                                 ['review'])])",
#             "config": {
#               "text_transformer:text_encoding:__choice__": "tfidf_encoding",
#               "text_transformer:text_feature_reduction:n_components": 573,
#               "text_transformer:text_encoding:tfidf_encoding:analyzer": "char",
#               "text_transformer:text_encoding:tfidf_encoding:binary": "False",
#               "text_transformer:text_encoding:tfidf_encoding:max_df": 0.970356057565052,
#               "text_transformer:text_encoding:tfidf_encoding:min_df": 0.0,
#               "text_transformer:text_encoding:tfidf_encoding:norm": "l2",
#               "text_transformer:text_encoding:tfidf_encoding:per_column": false,
#               "text_transformer:text_encoding:tfidf_encoding:sublinear_tf": "False",
#               "text_transformer:text_encoding:tfidf_encoding:ngram_range_char": 4
#             },
#             "dataset_properties": null,
#             "exclude": null,
#             "feat_type": {
#               "review": "string"
#             },
#             "force_sparse_output": false,
#             "include": null,
#             "init_params": {},
#             "pipeline": null,
#             "random_state": null
#           }
#         },
#         "feature_preprocessor": {
#           "algorithm": "NoPreprocessing",
#           "parameters": {}
#         }
#       }
#     ],
#     "graphic": {
#       "performance_over_time": {
#         "Timestamp": [
#           "2025-07-29T00:30:31",
#           "2025-07-29T00:30:31.700409",
#           "2025-07-29T00:34:16",
#           "2025-07-29T00:34:16",
#           "2025-07-29T00:34:16.721620",
#           "2025-07-29T00:34:16.721620",
#           "2025-07-29T00:41:15",
#           "2025-07-29T00:41:15",
#           "2025-07-29T00:41:15",
#           "2025-07-29T00:41:15",
#           "2025-07-29T00:41:15.709616",
#           "2025-07-29T00:41:15.709616",
#           "2025-07-29T00:41:15.709616",
#           "2025-07-29T00:41:15.709616",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T00:56:57.934353",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T03:04:25.975392",
#           "2025-07-29T08:05:13",
#           "2025-07-29T08:05:13",
#           "2025-07-29T08:05:13",
#           "2025-07-29T08:05:13",
#           "2025-07-29T08:05:13",
#           "2025-07-29T08:05:13",
#           "2025-07-29T08:05:13.812498",
#           "2025-07-29T08:05:13.812498",
#           "2025-07-29T08:34:50",
#           "2025-07-29T08:34:50",
#           "2025-07-29T08:34:50",
#           "2025-07-29T08:34:50",
#           "2025-07-29T08:34:50",
#           "2025-07-29T08:34:50",
#           "2025-07-29T08:34:50",
#           "2025-07-29T08:34:51.051427",
#           "2025-07-29T08:34:51.051427",
#           "2025-07-29T08:34:51.051427",
#           "2025-07-29T08:34:51.051427",
#           "2025-07-29T08:34:51.051427",
#           "2025-07-29T08:34:51.051427"
#         ],
#         "ensemble_optimization_score": [
#           NaN,
#           0.82204259423624,
#           0.82204259423624,
#           0.82204259423624,
#           0.8508271236599472,
#           0.8508271236599472,
#           0.8508271236599472,
#           0.8508271236599472,
#           0.8508271236599472,
#           0.8508271236599472,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8673126114481632,
#           0.8673126114481632,
#           0.8673126114481632,
#           0.8673126114481632,
#           0.8673126114481632,
#           0.8673126114481632,
#           0.8673126114481632,
#           0.8673126114481632,
#           0.8673126114481632,
#           0.879341904499706,
#           0.879341904499706,
#           0.879341904499706,
#           0.879341904499706,
#           0.879341904499706,
#           0.879341904499706
#         ],
#         "single_best_optimization_score": [
#           0.82204259423624,
#           0.82204259423624,
#           0.8508271236599472,
#           0.8508271236599472,
#           0.8508271236599472,
#           0.8508271236599472,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8673126114481632,
#           0.8673126114481632,
#           0.8673126114481632,
#           0.8673126114481632,
#           0.8673126114481632,
#           0.8673126114481632,
#           0.8673126114481632,
#           0.8673126114481632,
#           0.879341904499706,
#           0.879341904499706,
#           0.879341904499706,
#           0.879341904499706,
#           0.879341904499706,
#           0.879341904499706,
#           0.879341904499706,
#           0.879341904499706,
#           0.879341904499706,
#           0.879341904499706,
#           0.879341904499706,
#           0.879341904499706,
#           0.879341904499706
#         ],
#         "single_best_train_score": [
#           1.0,
#           1.0,
#           0.9995621890339201,
#           0.9995621890339201,
#           0.9995621890339201,
#           0.9995621890339201,
#           0.8578624921821421,
#           0.8578624921821421,
#           0.8578624921821421,
#           0.8578624921821421,
#           0.8578624921821421,
#           0.8578624921821421,
#           0.8578624921821421,
#           0.8578624921821421,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8948012386981533,
#           0.8948012386981533,
#           0.8948012386981533,
#           0.8948012386981533,
#           0.8948012386981533,
#           0.8948012386981533,
#           0.8948012386981533,
#           0.8948012386981533,
#           0.8840816846625659,
#           0.8840816846625659,
#           0.8840816846625659,
#           0.8840816846625659,
#           0.8840816846625659,
#           0.8840816846625659,
#           0.8840816846625659,
#           0.8840816846625659,
#           0.8840816846625659,
#           0.8840816846625659,
#           0.8840816846625659,
#           0.8840816846625659,
#           0.8840816846625659
#         ]
#       },
#       "learning_curve": null
#     }
#   }
# }
# Resultado para 'with_ensemble':
# Leaderboard:
#    rank  ensemble_weight               type      cost    duration  config_id  \
# 0     4             0.88                sgd  0.217024  161.597917         40
# 1     1             0.08                lda  0.125663  340.888424         95
# 2     2             0.02  gradient_boosting  0.149173  223.816619          2
# 3     3             0.02        extra_trees  0.182467  216.636513         14
#
#    train_loss  seed    start_time      end_time  budget              status  \
# 0    0.212358     0  1.753768e+09  1.753769e+09     0.0  StatusType.SUCCESS
# 1    0.123360     0  1.753789e+09  1.753789e+09     0.0  StatusType.SUCCESS
# 2    0.000438     0  1.753760e+09  1.753760e+09     0.0  StatusType.SUCCESS
# 3    0.000000     0  1.753763e+09  1.753763e+09     0.0  StatusType.SUCCESS
#
#   data_preprocessors               feature_preprocessors balancing_strategy  \
# 0                 []  [select_percentile_classification]               none
# 1                 []                  [no_preprocessing]               none
# 2                 []                  [no_preprocessing]          weighting
# 3                 []                          [fast_ica]               none
#
#     config_origin
# 0    Local Search
# 1    Local Search
# 2  Initial design
# 3  Initial design
# Objeto json:
# {
#   "timeStamp": "2025-07-29T09:24:59.180511-03:00",
#   "dataset": "imdb",
#   "automl": "autosklearn",
#   "with_ensemble": true,
#   "metrics": {
#     "accuracy": 0.87752,
#     "precision": 0.8776759433034124,
#     "recall": 0.87752,
#     "balanced_f1": 0.8775073556232886,
#     "confusion_matrix": [
#       [
#         0.86736,
#         0.13264
#       ],
#       [
#         0.11232,
#         0.88768
#       ]
#     ]
#   },
#   "model": {
#     "total_models": 4,
#     "models": [
#       {
#         "weight": 0.88,
#         "cost": 0.2170244161928494,
#         "classifier": {
#           "algorithm": "SGD",
#           "parameters": {
#             "alpha": 0.00012018150585937153,
#             "average": true,
#             "epsilon": 0.1,
#             "eta0": 0.025363335094880472,
#             "fit_intercept": true,
#             "l1_ratio": 0.15,
#             "learning_rate": "invscaling",
#             "loss": "perceptron",
#             "penalty": "l2",
#             "power_t": 0.5644024985248751,
#             "random_state": 1,
#             "tol": 0.00012385398647153238
#           }
#         },
#         "data_preprocessor": {
#           "algorithm": "FeatTypeSplit",
#           "parameters": {
#             "column_transformer": "ColumnTransformer(sparse_threshold=0.0,\n                  transformers=[('text_transformer',\n                                 TextPreprocessingPipeline(config=Configuration(values={\n  'text_encoding:__choice__': 'tfidf_encoding',\n  'text_encoding:tfidf_encoding:analyzer': 'char',\n  'text_encoding:tfidf_encoding:binary': 'False',\n  'text_encoding:tfidf_encoding:max_df': 1.0,\n  'text_encoding:tfidf_encoding:min_df': 0.0,\n  '...\n  'text_feature_reduction:n_components': 100,\n})\n, dataset_properties={'signed': False, 'sparse': False}, exclude={}, feat_type={'review': 'string'}, include={}, init_params={}, steps=[('text_encoding', <autosklearn.pipeline.components.data_preprocessing.text_encoding.BagOfWordChoice object at 0x7e8ecfce1850>), ('text_feature_reduction', TextFeatureReduction(n_components=100))]),\n                                 ['review'])])",
#             "config": {
#               "text_transformer:text_encoding:__choice__": "tfidf_encoding",
#               "text_transformer:text_feature_reduction:n_components": 100,
#               "text_transformer:text_encoding:tfidf_encoding:analyzer": "char",
#               "text_transformer:text_encoding:tfidf_encoding:binary": "False",
#               "text_transformer:text_encoding:tfidf_encoding:max_df": 1.0,
#               "text_transformer:text_encoding:tfidf_encoding:min_df": 0.0,
#               "text_transformer:text_encoding:tfidf_encoding:norm": "l2",
#               "text_transformer:text_encoding:tfidf_encoding:per_column": false,
#               "text_transformer:text_encoding:tfidf_encoding:sublinear_tf": "False",
#               "text_transformer:text_encoding:tfidf_encoding:ngram_range_char": 4
#             },
#             "dataset_properties": null,
#             "exclude": null,
#             "feat_type": {
#               "review": "string"
#             },
#             "force_sparse_output": false,
#             "include": null,
#             "init_params": {},
#             "pipeline": null,
#             "random_state": null
#           }
#         },
#         "feature_preprocessor": {
#           "algorithm": "SelectPercentileClassification",
#           "parameters": {
#             "percentile": 47,
#             "random_state": 1,
#             "score_func": "<function chi2 at 0x7e8e2fa2f160>"
#           }
#         }
#       },
#       {
#         "weight": 0.08,
#         "cost": 0.12566256402479015,
#         "classifier": {
#           "algorithm": "LDA",
#           "parameters": {}
#         },
#         "data_preprocessor": {
#           "algorithm": "FeatTypeSplit",
#           "parameters": {
#             "column_transformer": "ColumnTransformer(sparse_threshold=0.0,\n                  transformers=[('text_transformer',\n                                 TextPreprocessingPipeline(config=Configuration(values={\n  'text_encoding:__choice__': 'tfidf_encoding',\n  'text_encoding:tfidf_encoding:analyzer': 'char',\n  'text_encoding:tfidf_encoding:binary': 'False',\n  'text_encoding:tfidf_encoding:max_df': 0.9706346807885554,\n  'text_encoding:tfidf_encodin...\n  'text_feature_reduction:n_components': 422,\n})\n, dataset_properties={'signed': False, 'sparse': False}, exclude={}, feat_type={'review': 'string'}, include={}, init_params={}, steps=[('text_encoding', <autosklearn.pipeline.components.data_preprocessing.text_encoding.BagOfWordChoice object at 0x7e8ecfa9c310>), ('text_feature_reduction', TextFeatureReduction(n_components=422))]),\n                                 ['review'])])",
#             "config": {
#               "text_transformer:text_encoding:__choice__": "tfidf_encoding",
#               "text_transformer:text_feature_reduction:n_components": 422,
#               "text_transformer:text_encoding:tfidf_encoding:analyzer": "char",
#               "text_transformer:text_encoding:tfidf_encoding:binary": "False",
#               "text_transformer:text_encoding:tfidf_encoding:max_df": 0.9706346807885554,
#               "text_transformer:text_encoding:tfidf_encoding:min_df": 0.01316330780970093,
#               "text_transformer:text_encoding:tfidf_encoding:norm": "l2",
#               "text_transformer:text_encoding:tfidf_encoding:per_column": true,
#               "text_transformer:text_encoding:tfidf_encoding:sublinear_tf": "False",
#               "text_transformer:text_encoding:tfidf_encoding:ngram_range_char": 4
#             },
#             "dataset_properties": null,
#             "exclude": null,
#             "feat_type": {
#               "review": "string"
#             },
#             "force_sparse_output": false,
#             "include": null,
#             "init_params": {},
#             "pipeline": null,
#             "random_state": null
#           }
#         },
#         "feature_preprocessor": {
#           "algorithm": "NoPreprocessing",
#           "parameters": {}
#         }
#       },
#       {
#         "weight": 0.02,
#         "cost": 0.14917287634005283,
#         "classifier": {
#           "algorithm": "GradientBoostingClassifier",
#           "parameters": {
#             "early_stop": "off",
#             "l2_regularization": 1.0945814167023392e-10,
#             "learning_rate": 0.11042628136263043,
#             "loss": "auto",
#             "max_bins": 255,
#             "max_depth": null,
#             "max_leaf_nodes": 30,
#             "min_samples_leaf": 22,
#             "n_iter_no_change": 0,
#             "random_state": 1,
#             "scoring": "loss",
#             "tol": 1e-07,
#             "validation_fraction": null,
#             "verbose": 0
#           }
#         },
#         "data_preprocessor": {
#           "algorithm": "FeatTypeSplit",
#           "parameters": {
#             "column_transformer": "ColumnTransformer(sparse_threshold=0.0,\n                  transformers=[('text_transformer',\n                                 TextPreprocessingPipeline(config=Configuration(values={\n  'text_encoding:__choice__': 'tfidf_encoding',\n  'text_encoding:tfidf_encoding:analyzer': 'char',\n  'text_encoding:tfidf_encoding:binary': 'False',\n  'text_encoding:tfidf_encoding:max_df': 1.0,\n  'text_encoding:tfidf_encoding:min_df': 0.0,\n  '...\n  'text_feature_reduction:n_components': 100,\n})\n, dataset_properties={'signed': False, 'sparse': False}, exclude={}, feat_type={'review': 'string'}, include={}, init_params={}, steps=[('text_encoding', <autosklearn.pipeline.components.data_preprocessing.text_encoding.BagOfWordChoice object at 0x7e8ecfc70ee0>), ('text_feature_reduction', TextFeatureReduction(n_components=100))]),\n                                 ['review'])])",
#             "config": {
#               "text_transformer:text_encoding:__choice__": "tfidf_encoding",
#               "text_transformer:text_feature_reduction:n_components": 100,
#               "text_transformer:text_encoding:tfidf_encoding:analyzer": "char",
#               "text_transformer:text_encoding:tfidf_encoding:binary": "False",
#               "text_transformer:text_encoding:tfidf_encoding:max_df": 1.0,
#               "text_transformer:text_encoding:tfidf_encoding:min_df": 0.0,
#               "text_transformer:text_encoding:tfidf_encoding:norm": "l2",
#               "text_transformer:text_encoding:tfidf_encoding:per_column": false,
#               "text_transformer:text_encoding:tfidf_encoding:sublinear_tf": "False",
#               "text_transformer:text_encoding:tfidf_encoding:ngram_range_char": 4
#             },
#             "dataset_properties": null,
#             "exclude": null,
#             "feat_type": {
#               "review": "string"
#             },
#             "force_sparse_output": false,
#             "include": null,
#             "init_params": {},
#             "pipeline": null,
#             "random_state": null
#           }
#         },
#         "feature_preprocessor": {
#           "algorithm": "NoPreprocessing",
#           "parameters": {}
#         }
#       },
#       {
#         "weight": 0.02,
#         "cost": 0.18246690078011207,
#         "classifier": {
#           "algorithm": "ExtraTreesClassifier",
#           "parameters": {
#             "bootstrap": false,
#             "class_weight": null,
#             "criterion": "gini",
#             "max_depth": null,
#             "max_features": 0.4986263167495816,
#             "max_leaf_nodes": null,
#             "min_impurity_decrease": 0.0,
#             "min_samples_leaf": 1,
#             "min_samples_split": 4,
#             "min_weight_fraction_leaf": 0.0,
#             "n_jobs": 1,
#             "oob_score": false,
#             "random_state": 1,
#             "verbose": 0
#           }
#         },
#         "data_preprocessor": {
#           "algorithm": "FeatTypeSplit",
#           "parameters": {
#             "column_transformer": "ColumnTransformer(sparse_threshold=0.0,\n                  transformers=[('text_transformer',\n                                 TextPreprocessingPipeline(config=Configuration(values={\n  'text_encoding:__choice__': 'tfidf_encoding',\n  'text_encoding:tfidf_encoding:analyzer': 'char',\n  'text_encoding:tfidf_encoding:binary': 'False',\n  'text_encoding:tfidf_encoding:max_df': 1.0,\n  'text_encoding:tfidf_encoding:min_df': 0.0,\n  '...\n  'text_feature_reduction:n_components': 100,\n})\n, dataset_properties={'signed': False, 'sparse': False}, exclude={}, feat_type={'review': 'string'}, include={}, init_params={}, steps=[('text_encoding', <autosklearn.pipeline.components.data_preprocessing.text_encoding.BagOfWordChoice object at 0x7e8ecfb4e700>), ('text_feature_reduction', TextFeatureReduction(n_components=100))]),\n                                 ['review'])])",
#             "config": {
#               "text_transformer:text_encoding:__choice__": "tfidf_encoding",
#               "text_transformer:text_feature_reduction:n_components": 100,
#               "text_transformer:text_encoding:tfidf_encoding:analyzer": "char",
#               "text_transformer:text_encoding:tfidf_encoding:binary": "False",
#               "text_transformer:text_encoding:tfidf_encoding:max_df": 1.0,
#               "text_transformer:text_encoding:tfidf_encoding:min_df": 0.0,
#               "text_transformer:text_encoding:tfidf_encoding:norm": "l2",
#               "text_transformer:text_encoding:tfidf_encoding:per_column": false,
#               "text_transformer:text_encoding:tfidf_encoding:sublinear_tf": "False",
#               "text_transformer:text_encoding:tfidf_encoding:ngram_range_char": 4
#             },
#             "dataset_properties": null,
#             "exclude": null,
#             "feat_type": {
#               "review": "string"
#             },
#             "force_sparse_output": false,
#             "include": null,
#             "init_params": {},
#             "pipeline": null,
#             "random_state": null
#           }
#         },
#         "feature_preprocessor": {
#           "algorithm": "FastICA",
#           "parameters": {
#             "algorithm": "deflation",
#             "fun": "cube",
#             "n_components": null,
#             "random_state": 1,
#             "whiten": false
#           }
#         }
#       }
#     ],
#     "graphic": {
#       "performance_over_time": {
#         "Timestamp": [
#           "2025-07-29T00:30:32",
#           "2025-07-29T00:30:32.663579",
#           "2025-07-29T00:34:16",
#           "2025-07-29T00:34:16",
#           "2025-07-29T00:34:17.634693",
#           "2025-07-29T00:37:42.985751",
#           "2025-07-29T00:41:16",
#           "2025-07-29T00:41:16",
#           "2025-07-29T00:41:16",
#           "2025-07-29T00:41:16",
#           "2025-07-29T00:41:18.572111",
#           "2025-07-29T00:41:18.572111",
#           "2025-07-29T00:41:18.572111",
#           "2025-07-29T00:41:18.572111",
#           "2025-07-29T00:41:18.572111",
#           "2025-07-29T00:41:18.572111",
#           "2025-07-29T00:41:18.572111",
#           "2025-07-29T00:41:18.572111",
#           "2025-07-29T00:41:18.572111",
#           "2025-07-29T00:41:18.572111",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T00:57:03",
#           "2025-07-29T01:21:34.687274",
#           "2025-07-29T01:25:28.932992",
#           "2025-07-29T01:25:28.932992",
#           "2025-07-29T01:25:28.932992",
#           "2025-07-29T01:25:28.932992",
#           "2025-07-29T01:25:28.932992",
#           "2025-07-29T01:43:45.182520",
#           "2025-07-29T01:43:45.182520",
#           "2025-07-29T01:43:45.182520",
#           "2025-07-29T01:43:45.182520",
#           "2025-07-29T01:43:45.182520",
#           "2025-07-29T01:43:45.182520",
#           "2025-07-29T01:43:45.182520",
#           "2025-07-29T01:43:45.182520",
#           "2025-07-29T01:43:45.182520",
#           "2025-07-29T01:43:45.182520",
#           "2025-07-29T01:43:45.182520",
#           "2025-07-29T01:43:45.182520",
#           "2025-07-29T01:43:45.182520",
#           "2025-07-29T01:43:45.182520",
#           "2025-07-29T01:43:45.182520",
#           "2025-07-29T01:43:45.182520",
#           "2025-07-29T01:43:45.182520",
#           "2025-07-29T01:43:45.182520",
#           "2025-07-29T01:43:45.182520",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:27",
#           "2025-07-29T03:10:44.934103",
#           "2025-07-29T03:10:44.934103",
#           "2025-07-29T03:10:44.934103",
#           "2025-07-29T03:10:44.934103",
#           "2025-07-29T03:10:44.934103",
#           "2025-07-29T03:10:44.934103",
#           "2025-07-29T03:10:44.934103",
#           "2025-07-29T03:10:44.934103",
#           "2025-07-29T03:10:44.934103",
#           "2025-07-29T03:10:44.934103",
#           "2025-07-29T03:10:44.934103",
#           "2025-07-29T03:10:44.934103",
#           "2025-07-29T03:10:44.934103",
#           "2025-07-29T03:10:44.934103",
#           "2025-07-29T03:10:44.934103",
#           "2025-07-29T03:54:19.124863",
#           "2025-07-29T03:54:19.124863",
#           "2025-07-29T03:54:19.124863",
#           "2025-07-29T03:54:19.124863",
#           "2025-07-29T03:54:19.124863",
#           "2025-07-29T04:21:08.555756",
#           "2025-07-29T04:21:08.555756",
#           "2025-07-29T04:21:08.555756",
#           "2025-07-29T05:49:15.002714",
#           "2025-07-29T05:49:15.002714",
#           "2025-07-29T06:18:59.817197",
#           "2025-07-29T06:18:59.817197",
#           "2025-07-29T06:18:59.817197",
#           "2025-07-29T06:18:59.817197",
#           "2025-07-29T06:18:59.817197",
#           "2025-07-29T06:18:59.817197",
#           "2025-07-29T06:18:59.817197",
#           "2025-07-29T07:57:56.469570",
#           "2025-07-29T07:57:56.469570",
#           "2025-07-29T08:34:32",
#           "2025-07-29T08:34:32",
#           "2025-07-29T08:34:32",
#           "2025-07-29T08:34:32",
#           "2025-07-29T08:34:56.405994",
#           "2025-07-29T08:34:56.405994",
#           "2025-07-29T08:34:56.405994"
#         ],
#         "ensemble_optimization_score": [
#           NaN,
#           0.82204259423624,
#           0.82204259423624,
#           0.82204259423624,
#           0.8528457347248274,
#           0.8583960863154436,
#           0.8583960863154436,
#           0.8583960863154436,
#           0.8583960863154436,
#           0.8583960863154436,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.8626755455356938,
#           0.862848131168213,
#           0.8629360642672604,
#           0.8629360642672604,
#           0.8629360642672604,
#           0.8629360642672604,
#           0.8629360642672604,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.863012392900887,
#           0.8702182459013434,
#           0.8702182459013434,
#           0.8702182459013434,
#           0.8702182459013434,
#           0.8702182459013434,
#           0.8702182459013434,
#           0.8702182459013434,
#           0.8702182459013434,
#           0.8702182459013434,
#           0.8702182459013434,
#           0.8702182459013434,
#           0.8702182459013434,
#           0.8702182459013434,
#           0.8702182459013434,
#           0.8702182459013434,
#           0.8717572575386283,
#           0.8717572575386283,
#           0.8717572575386283,
#           0.8717572575386283,
#           0.8717572575386283,
#           0.872322121795083,
#           0.872322121795083,
#           0.872322121795083,
#           0.8727987085466538,
#           0.8727987085466538,
#           0.875910759339343,
#           0.875910759339343,
#           0.875910759339343,
#           0.875910759339343,
#           0.875910759339343,
#           0.875910759339343,
#           0.875910759339343,
#           0.8781795907567789,
#           0.8781795907567789,
#           0.8781795907567789,
#           0.8781795907567789,
#           0.8781795907567789,
#           0.8781795907567789,
#           0.878376595327687,
#           0.878376595327687,
#           0.878376595327687
#         ],
#         "single_best_optimization_score": [
#           0.82204259423624,
#           0.82204259423624,
#           0.8508271236599472,
#           0.8508271236599472,
#           0.8508271236599472,
#           0.8508271236599472,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8565895632265188,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8570500737941001,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8631808121627609,
#           0.8743374359752099,
#           0.8743374359752099,
#           0.8743374359752099,
#           0.8743374359752099,
#           0.8743374359752099,
#           0.8743374359752099,
#           0.8743374359752099
#         ],
#         "single_best_train_score": [
#           1.0,
#           1.0,
#           0.9995621890339201,
#           0.9995621890339201,
#           0.9995621890339201,
#           0.9995621890339201,
#           0.8578624921821421,
#           0.8578624921821421,
#           0.8578624921821421,
#           0.8578624921821421,
#           0.8578624921821421,
#           0.8578624921821421,
#           0.8578624921821421,
#           0.8578624921821421,
#           0.8578624921821421,
#           0.8578624921821421,
#           0.8578624921821421,
#           0.8578624921821421,
#           0.8578624921821421,
#           0.8578624921821421,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8582288543738987,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8658143587303287,
#           0.8766402252195956,
#           0.8766402252195956,
#           0.8766402252195956,
#           0.8766402252195956,
#           0.8766402252195956,
#           0.8766402252195956,
#           0.8766402252195956
#         ]
#       },
#       "learning_curve": null
#     }
#   }
# }

# %%
for label, result in RESULTS.items():
    doc = result['doc']
    mongo_insert(doc)

# %% [markdown]
# # Visualizações

# %%
# Plot comparativo - todas as curvas em um único gráfico
plt.figure(figsize=(12, 8))

colors = ['#1f77b4', '#ff7f0e']  # Cores diferentes para cada linha
line_styles = ['-', '--']  # Estilos de linha diferentes
markers = ['o', 's']  # Marcadores diferentes

for idx, (label, item) in enumerate(RESULTS.items()):
    perf = item['doc']['model']['graphic']['performance_over_time']
    
    # Converter timestamps para formato numérico (segundos desde o início)
    timestamps = pd.to_datetime(perf['Timestamp'], format='ISO8601')
    time_seconds = (timestamps - timestamps[0]).total_seconds()
    
    # Plot do ensemble optimization score
    if 'ensemble_optimization_score' in perf:
        ensemble_scores = np.array(perf['ensemble_optimization_score'])
        valid_mask = ~np.isnan(ensemble_scores)
        
        # Adicionar pequeno offset vertical para separar as linhas
        offset = idx * 0.001
        
        plt.plot(
            time_seconds[valid_mask], 
            ensemble_scores[valid_mask] + offset, 
            label=f'Ensemble - {label.replace("_", " ").title()}',
            linewidth=2.5,
            marker=markers[idx],
            markersize=6,
            color=colors[idx],
            linestyle=line_styles[idx],
            alpha=0.8,
            markeredgecolor='white',
            markeredgewidth=1
        )

plt.title('Comparativo de Performance - AutoSklearn', fontsize=14, fontweight='bold')
plt.xlabel('Tempo (s)', fontsize=12)
plt.ylabel('F1 Weighted Score', fontsize=12)
plt.legend(fontsize=10, loc='lower right')
plt.grid(True, alpha=0.3)
plt.ylim(0.8, 1.0)
plt.tight_layout()
plt.show()
