# %% [markdown]
# # 1. Configuração de Ambiente
#
# Imports agrupados por tipo e carregamento das variáveis de ambiente.

# %%
# %% Imports padrão
import os
import sys
from pathlib import Path
from datetime import datetime
import shutil
import json

# %% Imports de Data Science
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets, metrics, model_selection

# %% Configuração de paths e imports dos módulos personalizados
sys.path.insert(0, os.path.abspath(os.path.join('..', 'src')))
from mongo import mongo_insert
from metrics import evaluate_metrics, collect_performance_over_time, compute_learning_curve
# Out:
# /home/joao/miniconda3/envs/tcc-env/lib/python3.9/site-packages/sklearn/utils/fixes.py:28: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version  # type: ignore

# %% [markdown]
# # 2. Carregamento e Pré-processamento de Dados
#
# Carrega o dataset (definido por variável), divide em treino e teste e prepara diretórios temporários.

# %%
# %% Configurações de dataset
DATASET_NAME = 'imdb'
RANDOM_STATE = 1

# %% Carregamento
df = pd.read_csv(f'../data/{DATASET_NAME}.csv')
df.columns = df.columns.str.lower()
df.columns

X = df.drop(columns='sentiment')
y = df['sentiment']

# %% Split
X_train, X_test, y_train, y_test = model_selection.train_test_split(
    X, y, random_state=RANDOM_STATE, stratify=y
)

# %% Diretórios temporários
TMP_ROOT = Path('../results/tmp') / DATASET_NAME
if TMP_ROOT.exists():
    shutil.rmtree(TMP_ROOT)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((37500, 1), (12500, 1), (37500,), (12500,))

# %% [markdown]
# # 3. Configuração e Execução do AutoSklearn
#
# Funções utilitárias para rodar o AutoSklearn com ou sem ensemble e coletar informações essenciais do processo.

# %%
import autosklearn.classification
import autosklearn.metrics

# %% Parâmetros Auto-sklearn
TIME_LIMIT_SEC = 60 * 60 * 14 # 14 horas
METRIC_SK = autosklearn.metrics.f1_weighted

def run_autosklearn(with_ensemble: bool, tmp_dir: Path):
    automl = autosklearn.classification.AutoSklearnClassifier(
        time_left_for_this_task=TIME_LIMIT_SEC,
        per_run_time_limit=int(TIME_LIMIT_SEC / 10),
        tmp_folder=str(tmp_dir),
        seed=RANDOM_STATE,
        metric=METRIC_SK,
        ensemble_kwargs={'ensemble_size': 50 if with_ensemble else 1},
        memory_limit=1024*6,  # 6GB de memória
    )
    automl.fit(X_train, y_train)
    return automl

def extract_leaderboard(automl):
    lb = automl.leaderboard(detailed=True, ensemble_only=True).sort_values('ensemble_weight', ascending=False)
    return lb.reset_index(drop=True)

def serialize_models(automl, leaderboard_df):
    def serialize_param(value):
        """Converte parâmetros para tipos serializáveis"""
        if value is None:
            return None
        elif isinstance(value, (int, float, str, bool)):
            return value
        elif isinstance(value, np.number):
            return float(value)
        elif isinstance(value, (list, tuple)):
            return [serialize_param(v) for v in value]
        elif isinstance(value, dict):
            return {k: serialize_param(v) for k, v in value.items()}
        else:
            # Para objetos complexos, tenta converter para string
            return str(value)
    
    models_serialized = []
    for (_, row), (weight, pipeline) in zip(
        leaderboard_df.iterrows(),
        automl.get_models_with_weights()
    ):
        steps_info = {}
        for name, step in pipeline.steps:
            estimator = step.choice if hasattr(step, 'choice') else step
            
            # Obtém todos os parâmetros
            try:
                raw_params = estimator.get_params(deep=False)
            except AttributeError:
                raw_params = {}
            
            filtered_params = {}
            for k, v in raw_params.items():
                try:
                    filtered_params[k] = serialize_param(v)
                except Exception as e:
                    filtered_params[k] = {"_error": str(e), "_type": type(v).__name__}
            
            steps_info[name] = {
                'algorithm': estimator.__class__.__name__,
                'parameters': filtered_params
            }

        models_serialized.append({
            'weight': float(weight),
            'cost':   float(row['cost']),
            'classifier':          steps_info.get('classifier', {}),
            'data_preprocessor':   steps_info.get('data_preprocessor', {}),
            'feature_preprocessor':steps_info.get('feature_preprocessor', {})
        })

    return {
        'total_models': len(models_serialized),
        'models':       models_serialized
    }

# %% [markdown]
# # 4. Salvamento dos Resultados no MongoDB
#
# Constrói o documento JSON final (no padrão especificado) e insere na coleção MongoDB.

# %%
def build_document(automl, leaderboard_df, with_ensemble: bool):
    metrics_obj = evaluate_metrics(automl, X_test, y_test)
    model_obj = serialize_models(automl, leaderboard_df)
    perf_time = collect_performance_over_time(automl)
    #lc_data = compute_learning_curve(automl, X_train, y_train, scoring='f1_weighted', random_state=RANDOM_STATE)
    return {
        'timeStamp': datetime.now().astimezone().isoformat(),
        'time_spent': TIME_LIMIT_SEC,
        'dataset': DATASET_NAME,
        'automl': 'autosklearn',
        'with_ensemble': with_ensemble,
        'metrics': metrics_obj,
        'model': {
            **model_obj,
            'graphic': {
                'performance_over_time': perf_time,
                'learning_curve': None
            }
        }
    }

# A função mongo_insert agora está no módulo mongo.py e foi importada na célula de configuração

# %% [markdown]
# # Execução
#
# Roda com e sem ensemble, monta documentos e insere no MongoDB.

# %%
# %% Execução paralela limpa
import concurrent.futures, time, warnings, logging

warnings.filterwarnings("ignore", message=".*cost of smaller/equal to 0.*")

def workflow(with_ens: bool, label: str):
    folder = TMP_ROOT / label
    automl = run_autosklearn(with_ens, folder)
    lb     = extract_leaderboard(automl)
    doc    = build_document(automl, lb, with_ens)
    mongo  = mongo_insert(doc)  # Agora usa as variáveis de ambiente carregadas internamente
    return label, {'doc': doc, 'mongo_id': mongo, 'automl': automl, 'leaderboard': lb}

start = time.time()
RESULTS = {}

with concurrent.futures.ProcessPoolExecutor(max_workers=2) as pool:
    futures = [
        pool.submit(workflow, True , 'with_ensemble'),
        pool.submit(workflow, False, 'without_ensemble')
    ]
    for fut in concurrent.futures.as_completed(futures):
        label, data = fut.result()
        RESULTS[label] = data

print(f'Tempo total: {time.time()-start:.1f}s')
RESULTS.keys()
# Out:
# /home/joao/miniconda3/envs/tcc-env/lib/python3.9/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column review has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# /home/joao/miniconda3/envs/tcc-env/lib/python3.9/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column review has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# init_gesdd failed init
# init_gesdd failed init
# /home/joao/miniconda3/envs/tcc-env/lib/python3.9/site-packages/autosklearn/automl.py:1860: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pd.merge(
# Erro ao inserir no MongoDB: SSL handshake failed: ac-wvjp0kv-shard-00-00.qc5bvbn.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1147) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-wvjp0kv-shard-00-02.qc5bvbn.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1147) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-wvjp0kv-shard-00-01.qc5bvbn.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1147) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 5.0s, Topology Description: <TopologyDescription id: 688b8cc95d78d2c6ae5a505a, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-wvjp0kv-shard-00-00.qc5bvbn.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-wvjp0kv-shard-00-00.qc5bvbn.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1147) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('ac-wvjp0kv-shard-00-01.qc5bvbn.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-wvjp0kv-shard-00-01.qc5bvbn.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1147) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('ac-wvjp0kv-shard-00-02.qc5bvbn.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-wvjp0kv-shard-00-02.qc5bvbn.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1147) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
# /home/joao/miniconda3/envs/tcc-env/lib/python3.9/site-packages/autosklearn/automl.py:1860: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pd.merge(
# Erro ao inserir no MongoDB: SSL handshake failed: ac-wvjp0kv-shard-00-00.qc5bvbn.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1147) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-wvjp0kv-shard-00-02.qc5bvbn.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1147) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-wvjp0kv-shard-00-01.qc5bvbn.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1147) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 5.0s, Topology Description: <TopologyDescription id: 688b8d6a6fd5ec458f5a505a, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-wvjp0kv-shard-00-00.qc5bvbn.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-wvjp0kv-shard-00-00.qc5bvbn.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1147) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('ac-wvjp0kv-shard-00-01.qc5bvbn.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-wvjp0kv-shard-00-01.qc5bvbn.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1147) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('ac-wvjp0kv-shard-00-02.qc5bvbn.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-wvjp0kv-shard-00-02.qc5bvbn.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1147) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
# Tempo total: 50585.4s
# dict_keys(['without_ensemble', 'with_ensemble'])

# %%
# for label, result in RESULTS.items():
#     doc = result['doc']
#     mongo_insert(doc)

# %%
for label, result in RESULTS.items():
    print(f"Resultado para '{label}':")
    print(f"Leaderboard:")
    print(result['leaderboard'])
    print(f"Objeto json:")
    doc = result['doc']
    doc_copy = doc.copy()
    doc_copy.pop('_id', None)
    print(json.dumps(doc_copy, indent=2))
# Out:
# Resultado para 'without_ensemble':
# Leaderboard:
#    rank  ensemble_weight type      cost    duration  config_id  train_loss  \
# 0     1              1.0  mlp  0.124931  447.164176        144    0.121437
#
#    seed    start_time      end_time  budget              status  \
# 0     0  1.753969e+09  1.753969e+09     0.0  StatusType.SUCCESS
#
#   data_preprocessors    feature_preprocessors balancing_strategy config_origin
# 0                 []  [feature_agglomeration]          weighting  Local Search
# Objeto json:
# {
#   "timeStamp": "2025-07-31T12:33:29.161355-03:00",
#   "time_spent": 50400,
#   "dataset": "imdb",
#   "automl": "autosklearn",
#   "with_ensemble": false,
#   "metrics": {
#     "accuracy": 0.87784,
#     "precision": 0.8779098982147738,
#     "recall": 0.87784,
#     "balanced_f1": 0.877834351060393,
#     "confusion_matrix": [
#       [
#         0.87104,
#         0.12896
#       ],
#       [
#         0.11536,
#         0.88464
#       ]
#     ]
#   },
#   "model": {
#     "total_models": 1,
#     "models": [
#       {
#         "weight": 1.0,
#         "cost": 0.12493090819807562,
#         "classifier": {
#           "algorithm": "MLPClassifier",
#           "parameters": {
#             "activation": "relu",
#             "alpha": 0.006034424894700656,
#             "batch_size": "auto",
#             "beta_1": 0.9,
#             "beta_2": 0.999,
#             "early_stopping": "valid",
#             "epsilon": 1e-08,
#             "hidden_layer_depth": 1,
#             "learning_rate_init": 0.00012229351099903873,
#             "n_iter_no_change": 32,
#             "num_nodes_per_layer": 85,
#             "random_state": 1,
#             "shuffle": true,
#             "solver": "adam",
#             "tol": 0.0001,
#             "validation_fraction": 0.1,
#             "verbose": 0
#           }
#         },
#         "data_preprocessor": {
#           "algorithm": "FeatTypeSplit",
#           "parameters": {
#             "column_transformer": "ColumnTransformer(sparse_threshold=0.0,\n                  transformers=[('text_transformer',\n                                 TextPreprocessingPipeline(config=Configuration(values={\n  'text_encoding:__choice__': 'tfidf_encoding',\n  'text_encoding:tfidf_encoding:analyzer': 'char',\n  'text_encoding:tfidf_encoding:binary': 'False',\n  'text_encoding:tfidf_encoding:max_df': 0.9701825364521259,\n  'text_encoding:tfidf_encodin...\n  'text_feature_reduction:n_components': 549,\n})\n, dataset_properties={'signed': False, 'sparse': False}, exclude={}, feat_type={'review': 'string'}, include={}, init_params={}, steps=[('text_encoding', <autosklearn.pipeline.components.data_preprocessing.text_encoding.BagOfWordChoice object at 0x733b1a1f7ac0>), ('text_feature_reduction', TextFeatureReduction(n_components=549))]),\n                                 ['review'])])",
#             "config": {
#               "text_transformer:text_encoding:__choice__": "tfidf_encoding",
#               "text_transformer:text_feature_reduction:n_components": 549,
#               "text_transformer:text_encoding:tfidf_encoding:analyzer": "char",
#               "text_transformer:text_encoding:tfidf_encoding:binary": "False",
#               "text_transformer:text_encoding:tfidf_encoding:max_df": 0.9701825364521259,
#               "text_transformer:text_encoding:tfidf_encoding:min_df": 0.0029195301553214385,
#               "text_transformer:text_encoding:tfidf_encoding:norm": "l2",
#               "text_transformer:text_encoding:tfidf_encoding:per_column": true,
#               "text_transformer:text_encoding:tfidf_encoding:sublinear_tf": "False",
#               "text_transformer:text_encoding:tfidf_encoding:ngram_range_char": 4
#             },
#             "dataset_properties": null,
#             "exclude": null,
#             "feat_type": {
#               "review": "string"
#             },
#             "force_sparse_output": false,
#             "include": null,
#             "init_params": {},
#             "pipeline": null,
#             "random_state": null
#           }
#         },
#         "feature_preprocessor": {
#           "algorithm": "FeatureAgglomeration",
#           "parameters": {
#             "affinity": "manhattan",
#             "linkage": "complete",
#             "n_clusters": 314,
#             "pooling_func": "<function mean at 0x733b086fe550>",
#             "random_state": 1
#           }
#         }
#       }
#     ],
#     "graphic": {
#       "performance_over_time": {
#         "Timestamp": [
#           "2025-07-31T02:09:33",
#           "2025-07-31T02:09:33.545611",
#           "2025-07-31T02:13:11",
#           "2025-07-31T02:13:11.671430",
#           "2025-07-31T02:16:31",
#           "2025-07-31T02:16:31.494524",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T02:20:00.699038",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:08",
#           "2025-07-31T05:48:09.169041",
#           "2025-07-31T05:48:09.169041",
#           "2025-07-31T05:48:09.169041",
#           "2025-07-31T05:48:09.169041",
#           "2025-07-31T05:48:09.169041",
#           "2025-07-31T05:48:09.169041",
#           "2025-07-31T05:48:09.169041",
#           "2025-07-31T05:48:09.169041",
#           "2025-07-31T05:48:09.169041",
#           "2025-07-31T05:48:09.169041",
#           "2025-07-31T05:48:09.169041",
#           "2025-07-31T05:48:09.169041",
#           "2025-07-31T05:48:09.169041",
#           "2025-07-31T05:48:09.169041",
#           "2025-07-31T05:48:09.169041",
#           "2025-07-31T05:48:09.169041",
#           "2025-07-31T05:48:09.169041",
#           "2025-07-31T07:23:18",
#           "2025-07-31T07:23:18",
#           "2025-07-31T07:23:18",
#           "2025-07-31T07:23:18",
#           "2025-07-31T07:23:18",
#           "2025-07-31T07:23:18",
#           "2025-07-31T07:23:18",
#           "2025-07-31T07:23:18",
#           "2025-07-31T07:23:18",
#           "2025-07-31T07:23:18",
#           "2025-07-31T07:23:18",
#           "2025-07-31T07:23:18",
#           "2025-07-31T07:23:18",
#           "2025-07-31T07:23:18",
#           "2025-07-31T07:23:18",
#           "2025-07-31T07:23:18",
#           "2025-07-31T07:23:18",
#           "2025-07-31T07:23:18",
#           "2025-07-31T07:23:18",
#           "2025-07-31T07:23:18",
#           "2025-07-31T07:23:18",
#           "2025-07-31T07:23:19.586723",
#           "2025-07-31T07:23:19.586723",
#           "2025-07-31T07:23:19.586723",
#           "2025-07-31T07:23:19.586723",
#           "2025-07-31T07:23:19.586723",
#           "2025-07-31T07:23:19.586723",
#           "2025-07-31T07:23:19.586723",
#           "2025-07-31T07:23:19.586723",
#           "2025-07-31T07:23:19.586723",
#           "2025-07-31T09:52:56",
#           "2025-07-31T09:52:56",
#           "2025-07-31T09:52:56",
#           "2025-07-31T09:52:56",
#           "2025-07-31T09:52:57.003519",
#           "2025-07-31T09:52:57.003519",
#           "2025-07-31T10:25:25",
#           "2025-07-31T10:25:25",
#           "2025-07-31T10:25:25",
#           "2025-07-31T10:25:25.756512",
#           "2025-07-31T10:25:25.756512",
#           "2025-07-31T10:42:59",
#           "2025-07-31T10:42:59",
#           "2025-07-31T10:42:59",
#           "2025-07-31T10:42:59",
#           "2025-07-31T10:42:59",
#           "2025-07-31T10:42:59",
#           "2025-07-31T10:42:59",
#           "2025-07-31T10:42:59",
#           "2025-07-31T10:42:59",
#           "2025-07-31T10:42:59",
#           "2025-07-31T10:42:59",
#           "2025-07-31T10:42:59",
#           "2025-07-31T10:43:00.433223",
#           "2025-07-31T10:43:00.433223",
#           "2025-07-31T10:43:00.433223",
#           "2025-07-31T10:43:00.433223",
#           "2025-07-31T10:43:00.433223",
#           "2025-07-31T10:43:00.433223"
#         ],
#         "ensemble_optimization_score": [
#           NaN,
#           0.8204375827786131,
#           0.8204375827786131,
#           0.8488078122688166,
#           0.8488078122688166,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.864560480979728,
#           0.864560480979728,
#           0.864560480979728,
#           0.864560480979728,
#           0.864560480979728,
#           0.8733685113834024,
#           0.8733685113834024,
#           0.8733685113834024,
#           0.8733685113834024,
#           0.8733685113834024,
#           0.8733685113834024,
#           0.8733685113834024,
#           0.8733685113834024,
#           0.8733685113834024,
#           0.8733685113834024,
#           0.8733685113834024,
#           0.8733685113834024,
#           0.8733685113834024,
#           0.8733685113834024,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244
#         ],
#         "single_best_optimization_score": [
#           0.8204375827786131,
#           0.8204375827786131,
#           0.8488078122688166,
#           0.8488078122688166,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.864560480979728,
#           0.864560480979728,
#           0.864560480979728,
#           0.864560480979728,
#           0.864560480979728,
#           0.864560480979728,
#           0.8733685113834024,
#           0.8733685113834024,
#           0.8733685113834024,
#           0.8733685113834024,
#           0.8733685113834024,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244
#         ],
#         "single_best_train_score": [
#           1.0,
#           1.0,
#           0.9994029850727353,
#           0.9994029850727353,
#           0.853255119929734,
#           0.853255119929734,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8644718023540796,
#           0.8644718023540796,
#           0.8644718023540796,
#           0.8644718023540796,
#           0.8644718023540796,
#           0.8644718023540796,
#           0.8746154726011437,
#           0.8746154726011437,
#           0.8746154726011437,
#           0.8746154726011437,
#           0.8746154726011437,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512
#         ]
#       },
#       "learning_curve": null
#     }
#   }
# }
# Resultado para 'with_ensemble':
# Leaderboard:
#     rank  ensemble_weight         type      cost    duration  config_id  \
# 0     10             0.30  extra_trees  0.157010  558.523983        149
# 1      1             0.22          mlp  0.124931  550.887447        144
# 2      4             0.16   libsvm_svc  0.130926  547.207644        147
# 3      2             0.10          mlp  0.126631  397.245388        141
# 4      5             0.04          mlp  0.135440  226.052825        137
# 5      8             0.04          lda  0.147482  135.285895         62
# 6      3             0.02          mlp  0.129294  296.163281        142
# 7      6             0.02          mlp  0.140548  167.052718         71
# 8      7             0.02          mlp  0.144001  276.075336        102
# 9      9             0.02          mlp  0.156323  184.103422         56
# 10    11             0.02          mlp  0.159983  184.624870         96
# 11    12             0.02          mlp  0.161508  188.097221         73
# 12    13             0.02   libsvm_svc  0.163005  309.567186         22
#
#     train_loss  seed    start_time      end_time  budget              status  \
# 0     0.000239     0  1.753973e+09  1.753974e+09     0.0  StatusType.SUCCESS
# 1     0.121437     0  1.753971e+09  1.753971e+09     0.0  StatusType.SUCCESS
# 2     0.129734     0  1.753972e+09  1.753973e+09     0.0  StatusType.SUCCESS
# 3     0.125385     0  1.753970e+09  1.753970e+09     0.0  StatusType.SUCCESS
# 4     0.135528     0  1.753968e+09  1.753968e+09     0.0  StatusType.SUCCESS
# 5     0.147429     0  1.753951e+09  1.753951e+09     0.0  StatusType.SUCCESS
# 6     0.129433     0  1.753970e+09  1.753971e+09     0.0  StatusType.SUCCESS
# 7     0.138056     0  1.753952e+09  1.753952e+09     0.0  StatusType.SUCCESS
# 8     0.120716     0  1.753956e+09  1.753956e+09     0.0  StatusType.SUCCESS
# 9     0.139085     0  1.753950e+09  1.753950e+09     0.0  StatusType.SUCCESS
# 10    0.150289     0  1.753956e+09  1.753956e+09     0.0  StatusType.SUCCESS
# 11    0.163530     0  1.753953e+09  1.753953e+09     0.0  StatusType.SUCCESS
# 12    0.160405     0  1.753943e+09  1.753943e+09     0.0  StatusType.SUCCESS
#
#    data_preprocessors    feature_preprocessors balancing_strategy  \
# 0                  []  [feature_agglomeration]          weighting
# 1                  []  [feature_agglomeration]          weighting
# 2                  []  [feature_agglomeration]          weighting
# 3                  []  [feature_agglomeration]               none
# 4                  []  [feature_agglomeration]          weighting
# 5                  []       [nystroem_sampler]               none
# 6                  []  [feature_agglomeration]          weighting
# 7                  []  [feature_agglomeration]               none
# 8                  []  [feature_agglomeration]          weighting
# 9                  []  [feature_agglomeration]               none
# 10                 []  [feature_agglomeration]               none
# 11                 []  [feature_agglomeration]               none
# 12                 []  [feature_agglomeration]          weighting
#
#      config_origin
# 0     Local Search
# 1     Local Search
# 2     Local Search
# 3     Local Search
# 4     Local Search
# 5     Local Search
# 6     Local Search
# 7     Local Search
# 8     Local Search
# 9     Local Search
# 10    Local Search
# 11    Local Search
# 12  Initial design
# Objeto json:
# {
#   "timeStamp": "2025-07-31T12:36:10.438120-03:00",
#   "time_spent": 50400,
#   "dataset": "imdb",
#   "automl": "autosklearn",
#   "with_ensemble": true,
#   "metrics": {
#     "accuracy": 0.8792,
#     "precision": 0.8792821822563999,
#     "recall": 0.8792,
#     "balanced_f1": 0.8791934559578317,
#     "confusion_matrix": [
#       [
#         0.87184,
#         0.12816
#       ],
#       [
#         0.11344,
#         0.88656
#       ]
#     ]
#   },
#   "model": {
#     "total_models": 13,
#     "models": [
#       {
#         "weight": 0.3,
#         "cost": 0.15701012151545257,
#         "classifier": {
#           "algorithm": "ExtraTreesClassifier",
#           "parameters": {
#             "bootstrap": false,
#             "class_weight": null,
#             "criterion": "entropy",
#             "max_depth": null,
#             "max_features": 0.4329855777551302,
#             "max_leaf_nodes": null,
#             "min_impurity_decrease": 0.0,
#             "min_samples_leaf": 7,
#             "min_samples_split": 3,
#             "min_weight_fraction_leaf": 0.0,
#             "n_jobs": 1,
#             "oob_score": false,
#             "random_state": 1,
#             "verbose": 0
#           }
#         },
#         "data_preprocessor": {
#           "algorithm": "FeatTypeSplit",
#           "parameters": {
#             "column_transformer": "ColumnTransformer(sparse_threshold=0.0,\n                  transformers=[('text_transformer',\n                                 TextPreprocessingPipeline(config=Configuration(values={\n  'text_encoding:__choice__': 'tfidf_encoding',\n  'text_encoding:tfidf_encoding:analyzer': 'char',\n  'text_encoding:tfidf_encoding:binary': 'False',\n  'text_encoding:tfidf_encoding:max_df': 0.9895198550416022,\n  'text_encoding:tfidf_encodin...\n  'text_feature_reduction:n_components': 909,\n})\n, dataset_properties={'signed': False, 'sparse': False}, exclude={}, feat_type={'review': 'string'}, include={}, init_params={}, steps=[('text_encoding', <autosklearn.pipeline.components.data_preprocessing.text_encoding.BagOfWordChoice object at 0x733b1a071e20>), ('text_feature_reduction', TextFeatureReduction(n_components=909))]),\n                                 ['review'])])",
#             "config": {
#               "text_transformer:text_encoding:__choice__": "tfidf_encoding",
#               "text_transformer:text_feature_reduction:n_components": 909,
#               "text_transformer:text_encoding:tfidf_encoding:analyzer": "char",
#               "text_transformer:text_encoding:tfidf_encoding:binary": "False",
#               "text_transformer:text_encoding:tfidf_encoding:max_df": 0.9895198550416022,
#               "text_transformer:text_encoding:tfidf_encoding:min_df": 0.007241368591172698,
#               "text_transformer:text_encoding:tfidf_encoding:norm": "l2",
#               "text_transformer:text_encoding:tfidf_encoding:per_column": false,
#               "text_transformer:text_encoding:tfidf_encoding:sublinear_tf": "False",
#               "text_transformer:text_encoding:tfidf_encoding:ngram_range_char": 4
#             },
#             "dataset_properties": null,
#             "exclude": null,
#             "feat_type": {
#               "review": "string"
#             },
#             "force_sparse_output": false,
#             "include": null,
#             "init_params": {},
#             "pipeline": null,
#             "random_state": null
#           }
#         },
#         "feature_preprocessor": {
#           "algorithm": "FeatureAgglomeration",
#           "parameters": {
#             "affinity": "manhattan",
#             "linkage": "complete",
#             "n_clusters": 249,
#             "pooling_func": "<function mean at 0x733b086fe550>",
#             "random_state": 1
#           }
#         }
#       },
#       {
#         "weight": 0.22,
#         "cost": 0.12493090819807562,
#         "classifier": {
#           "algorithm": "MLPClassifier",
#           "parameters": {
#             "activation": "relu",
#             "alpha": 0.006034424894700656,
#             "batch_size": "auto",
#             "beta_1": 0.9,
#             "beta_2": 0.999,
#             "early_stopping": "valid",
#             "epsilon": 1e-08,
#             "hidden_layer_depth": 1,
#             "learning_rate_init": 0.00012229351099903873,
#             "n_iter_no_change": 32,
#             "num_nodes_per_layer": 85,
#             "random_state": 1,
#             "shuffle": true,
#             "solver": "adam",
#             "tol": 0.0001,
#             "validation_fraction": 0.1,
#             "verbose": 0
#           }
#         },
#         "data_preprocessor": {
#           "algorithm": "FeatTypeSplit",
#           "parameters": {
#             "column_transformer": "ColumnTransformer(sparse_threshold=0.0,\n                  transformers=[('text_transformer',\n                                 TextPreprocessingPipeline(config=Configuration(values={\n  'text_encoding:__choice__': 'tfidf_encoding',\n  'text_encoding:tfidf_encoding:analyzer': 'char',\n  'text_encoding:tfidf_encoding:binary': 'False',\n  'text_encoding:tfidf_encoding:max_df': 0.9701825364521259,\n  'text_encoding:tfidf_encodin...\n  'text_feature_reduction:n_components': 549,\n})\n, dataset_properties={'signed': False, 'sparse': False}, exclude={}, feat_type={'review': 'string'}, include={}, init_params={}, steps=[('text_encoding', <autosklearn.pipeline.components.data_preprocessing.text_encoding.BagOfWordChoice object at 0x733b1a235280>), ('text_feature_reduction', TextFeatureReduction(n_components=549))]),\n                                 ['review'])])",
#             "config": {
#               "text_transformer:text_encoding:__choice__": "tfidf_encoding",
#               "text_transformer:text_feature_reduction:n_components": 549,
#               "text_transformer:text_encoding:tfidf_encoding:analyzer": "char",
#               "text_transformer:text_encoding:tfidf_encoding:binary": "False",
#               "text_transformer:text_encoding:tfidf_encoding:max_df": 0.9701825364521259,
#               "text_transformer:text_encoding:tfidf_encoding:min_df": 0.0029195301553214385,
#               "text_transformer:text_encoding:tfidf_encoding:norm": "l2",
#               "text_transformer:text_encoding:tfidf_encoding:per_column": true,
#               "text_transformer:text_encoding:tfidf_encoding:sublinear_tf": "False",
#               "text_transformer:text_encoding:tfidf_encoding:ngram_range_char": 4
#             },
#             "dataset_properties": null,
#             "exclude": null,
#             "feat_type": {
#               "review": "string"
#             },
#             "force_sparse_output": false,
#             "include": null,
#             "init_params": {},
#             "pipeline": null,
#             "random_state": null
#           }
#         },
#         "feature_preprocessor": {
#           "algorithm": "FeatureAgglomeration",
#           "parameters": {
#             "affinity": "manhattan",
#             "linkage": "complete",
#             "n_clusters": 314,
#             "pooling_func": "<function mean at 0x733b086fe550>",
#             "random_state": 1
#           }
#         }
#       },
#       {
#         "weight": 0.16,
#         "cost": 0.1309264513907038,
#         "classifier": {
#           "algorithm": "LibSVM_SVC",
#           "parameters": {
#             "C": 2.8283203235197925,
#             "class_weight": "balanced",
#             "coef0": 0.0,
#             "degree": 3,
#             "gamma": 0.04884023930848534,
#             "kernel": "rbf",
#             "max_iter": -1.0,
#             "random_state": 1,
#             "shrinking": false,
#             "tol": 0.0017157183382109408
#           }
#         },
#         "data_preprocessor": {
#           "algorithm": "FeatTypeSplit",
#           "parameters": {
#             "column_transformer": "ColumnTransformer(sparse_threshold=0.0,\n                  transformers=[('text_transformer',\n                                 TextPreprocessingPipeline(config=Configuration(values={\n  'text_encoding:__choice__': 'tfidf_encoding',\n  'text_encoding:tfidf_encoding:analyzer': 'char',\n  'text_encoding:tfidf_encoding:binary': 'False',\n  'text_encoding:tfidf_encoding:max_df': 0.8294922477503166,\n  'text_encoding:tfidf_encodin...\n  'text_feature_reduction:n_components': 286,\n})\n, dataset_properties={'signed': False, 'sparse': False}, exclude={}, feat_type={'review': 'string'}, include={}, init_params={}, steps=[('text_encoding', <autosklearn.pipeline.components.data_preprocessing.text_encoding.BagOfWordChoice object at 0x733b1a02dbb0>), ('text_feature_reduction', TextFeatureReduction(n_components=286))]),\n                                 ['review'])])",
#             "config": {
#               "text_transformer:text_encoding:__choice__": "tfidf_encoding",
#               "text_transformer:text_feature_reduction:n_components": 286,
#               "text_transformer:text_encoding:tfidf_encoding:analyzer": "char",
#               "text_transformer:text_encoding:tfidf_encoding:binary": "False",
#               "text_transformer:text_encoding:tfidf_encoding:max_df": 0.8294922477503166,
#               "text_transformer:text_encoding:tfidf_encoding:min_df": 0.001821734371002921,
#               "text_transformer:text_encoding:tfidf_encoding:norm": "l2",
#               "text_transformer:text_encoding:tfidf_encoding:per_column": true,
#               "text_transformer:text_encoding:tfidf_encoding:sublinear_tf": "False",
#               "text_transformer:text_encoding:tfidf_encoding:ngram_range_char": 4
#             },
#             "dataset_properties": null,
#             "exclude": null,
#             "feat_type": {
#               "review": "string"
#             },
#             "force_sparse_output": false,
#             "include": null,
#             "init_params": {},
#             "pipeline": null,
#             "random_state": null
#           }
#         },
#         "feature_preprocessor": {
#           "algorithm": "FeatureAgglomeration",
#           "parameters": {
#             "affinity": "manhattan",
#             "linkage": "complete",
#             "n_clusters": 248,
#             "pooling_func": "<function mean at 0x733b086fe550>",
#             "random_state": 1
#           }
#         }
#       },
#       {
#         "weight": 0.1,
#         "cost": 0.12663148861659757,
#         "classifier": {
#           "algorithm": "MLPClassifier",
#           "parameters": {
#             "activation": "tanh",
#             "alpha": 0.005752853977629231,
#             "batch_size": "auto",
#             "beta_1": 0.9,
#             "beta_2": 0.999,
#             "early_stopping": "train",
#             "epsilon": 1e-08,
#             "hidden_layer_depth": 1,
#             "learning_rate_init": 0.00012229351099903873,
#             "n_iter_no_change": 32,
#             "num_nodes_per_layer": 99,
#             "random_state": 1,
#             "shuffle": true,
#             "solver": "adam",
#             "tol": 0.0001,
#             "validation_fraction": 0.0,
#             "verbose": 0
#           }
#         },
#         "data_preprocessor": {
#           "algorithm": "FeatTypeSplit",
#           "parameters": {
# ...
#           0.8731158756396611,
#           0.8731158756396611,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8731986611371905,
#           0.8734408995286045,
#           0.873444455092675,
#           0.873444455092675,
#           0.8741696887515351,
#           0.8741696887515351,
#           0.8741696887515351,
#           0.8752972849820043,
#           0.8752972849820043,
#           0.8752972849820043,
#           0.8752972849820043,
#           0.8752972849820043,
#           0.8752972849820043,
#           0.8752972849820043,
#           0.8752972849820043,
#           0.8752972849820043,
#           0.8752972849820043,
#           0.8752972849820043,
#           0.8752972849820043,
#           0.8752972849820043,
#           0.8752972849820043,
#           0.8752972849820043,
#           0.8752972849820043,
#           0.8752972849820043,
#           0.8752972849820043,
#           0.8752972849820043,
#           0.8752972849820043,
#           0.8752972849820043,
#           0.8752972849820043,
#           0.8752972849820043,
#           0.8752972849820043,
#           0.8759595959595959,
#           0.8760403457600122,
#           0.8760403457600122,
#           0.8760403457600122,
#           0.8770908994598314,
#           0.8771705285039609
#         ],
#         "single_best_optimization_score": [
#           0.8204375827786131,
#           0.8204375827786131,
#           0.8488078122688166,
#           0.8488078122688166,
#           0.8506039761074067,
#           0.8506039761074067,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.856319207327651,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8594522516808064,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.8636001459990688,
#           0.864560480979728,
#           0.864560480979728,
#           0.864560480979728,
#           0.864560480979728,
#           0.8733685113834024,
#           0.8733685113834024,
#           0.8733685113834024,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244,
#           0.8750690918019244
#         ],
#         "single_best_train_score": [
#           1.0,
#           1.0,
#           0.9994029850727353,
#           0.9994029850727353,
#           0.853255119929734,
#           0.853255119929734,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8569932904876284,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8619442671301062,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8636185673053596,
#           0.8644718023540796,
#           0.8644718023540796,
#           0.8644718023540796,
#           0.8644718023540796,
#           0.8746154726011437,
#           0.8746154726011437,
#           0.8746154726011437,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512,
#           0.8785626903961512
#         ]
#       },
#       "learning_curve": null
#     }
#   }
# }

# %% [markdown]
# # Visualizações

# %%
# Plot comparativo - todas as curvas em um único gráfico
plt.figure(figsize=(12, 8))

colors = ['#1f77b4', '#ff7f0e']  # Cores diferentes para cada linha
line_styles = ['-', '--']  # Estilos de linha diferentes
markers = ['o', 's']  # Marcadores diferentes

for idx, (label, item) in enumerate(RESULTS.items()):
    perf = item['doc']['model']['graphic']['performance_over_time']
    
    # Converter timestamps para formato numérico (segundos desde o início)
    timestamps = pd.to_datetime(perf['Timestamp'], format='ISO8601')
    time_seconds = (timestamps - timestamps[0]).total_seconds()
    
    # Plot do ensemble optimization score
    if 'ensemble_optimization_score' in perf:
        ensemble_scores = np.array(perf['ensemble_optimization_score'])
        valid_mask = ~np.isnan(ensemble_scores)
        
        # Adicionar pequeno offset vertical para separar as linhas
        offset = idx * 0.001
        
        plt.plot(
            time_seconds[valid_mask], 
            ensemble_scores[valid_mask] + offset, 
            label=f'Ensemble - {label.replace("_", " ").title()}',
            linewidth=2.5,
            marker=markers[idx],
            markersize=6,
            color=colors[idx],
            linestyle=line_styles[idx],
            alpha=0.8,
            markeredgecolor='white',
            markeredgewidth=1
        )

plt.title('Comparativo de Performance - AutoSklearn', fontsize=14, fontweight='bold')
plt.xlabel('Tempo (s)', fontsize=12)
plt.ylabel('F1 Weighted Score', fontsize=12)
plt.legend(fontsize=10, loc='lower right')
plt.grid(True, alpha=0.3)
plt.ylim(0.8, 1.0)
plt.tight_layout()
plt.show()
